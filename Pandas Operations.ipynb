# %%
import pandas as pd
import numpy as np

# %%
sozluk={"Ankara": [20,np.nan,25],"Amasya":[20,np.nan,23],"İstanbul":[np.nan,30,42]}
havaDF=pd.DataFrame(sozluk)

# %%
havaDF
# Out:
#    Ankara  Amasya  İstanbul
# 0    20.0    20.0       NaN
# 1     NaN     NaN      30.0
# 2    25.0    23.0      42.0

# %%
havaDF.fillna(20)
# Out:
#    Ankara  Amasya  İstanbul
# 0    20.0    20.0      20.0
# 1    20.0    20.0      30.0
# 2    25.0    23.0      42.0

# %%
maasSozluk={"Departman":["yazılım","satış","hukuk","finans","finans","hukuk"],
           "Çalışanlar":["Ahmet","mehmet","atil","burak","zeynep","emir"],
            "Maas":[100,150,300,200,500,650]}

# %%
maasDataFrame=pd.DataFrame(maasSozluk)
maasDataFrame
# Out:
#   Departman Çalışanlar  Maas
# 0   yazılım      Ahmet   100
# 1     satış     mehmet   150
# 2     hukuk       atil   300
# 3    finans      burak   200
# 4    finans     zeynep   500
# 5     hukuk       emir   650

# %%
grupObje=maasDataFrame.groupby("Departman")

# %%
grupObje.count()
# Out:
#            Çalışanlar  Maas
# Departman
# finans              2     2
# hukuk               2     2
# satış               1     1
# yazılım             1     1

# %%
grupObje.mean()
# Out:
#            Maas
# Departman
# finans      350
# hukuk       475
# satış       150
# yazılım     100

# %%
grupObje.min()
# Out:
#           Çalışanlar  Maas
# Departman
# finans         burak   200
# hukuk           atil   300
# satış         mehmet   150
# yazılım        Ahmet   100

# %%
grupObje.max()
# Out:
#           Çalışanlar  Maas
# Departman
# finans        zeynep   500
# hukuk           emir   650
# satış         mehmet   150
# yazılım        Ahmet   100

# %%
grupObje.describe()
# Out:
#            Maas
#           count   mean         std    min    25%    50%    75%    max
# Departman
# finans      2.0  350.0  212.132034  200.0  275.0  350.0  425.0  500.0
# hukuk       2.0  475.0  247.487373  300.0  387.5  475.0  562.5  650.0
# satış       1.0  150.0         NaN  150.0  150.0  150.0  150.0  150.0
# yazılım     1.0  100.0         NaN  100.0  100.0  100.0  100.0  100.0
