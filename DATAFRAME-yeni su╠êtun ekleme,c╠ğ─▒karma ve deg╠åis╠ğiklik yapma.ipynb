# %%
import pandas as pd

# %%
dünya = pd.read_csv("dünya.csv")
dünya.head()
# Out:
#         Ülke     Gelir     Nüfus  Kişi Başına           KITA
# 0        ABD  20410000   323,766        63039  Kuzey Amerika
# 1        Çin  14090000  1415,045         9957           Asya
# 2    Japonya   5170000   127,185        40649           Asya
# 3    Almanya   4210000    82,293        51158         Avrupa
# 4  İngiltere   2940000    66,573        44162         Avrupa

# %%
dünya[["Ülke","KITA"]].head()
# Out:
#         Ülke           KITA
# 0        ABD  Kuzey Amerika
# 1        Çin           Asya
# 2    Japonya           Asya
# 3    Almanya         Avrupa
# 4  İngiltere         Avrupa

# %%
dünya["Sıralama"] = "top 20"

# %%
dünya
# Out:
#                Ülke   Gelir  gelir düzeyi     Nüfus  Kişi Başına  \
# 0               ABD  20.410  yüksek gelir   323,766        63039
# 1               Çin  14.090  yüksek gelir  1415,045         9957
# 2           Japonya   5.170  yüksek gelir   127,185        40649
# 3           Almanya   4.210  yüksek gelir    82,293        51158
# 4         İngiltere   2.940  yüksek gelir    66,573        44162
# 5            Fransa   2.930  yüksek gelir    65,233        44915
# 6         Hindistan   2.850  yüksek gelir  1354,051         2104
# 7            İtalya   2.180  yüksek gelir     59,29        36768
# 8          Brezilya   2.140  yüksek gelir   210,867        10148
# 9            Kanada   1.800  yüksek gelir    36,953        48710
# 10            Rusya   1.720  yüksek gelir   143,967        11947
# 11       GÜney Kore   1.690  yüksek gelir    51,164        33031
# 12          İspanya   1.510  yüksek gelir    46,397        32545
# ...

# %%
dünya.insert(2,column="gelir düzeyi",value="yüksek gelir")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-dab059e05bc2> in <module>()
# ----> 1 dünya.insert(2,column="gelir düzeyi",value="yüksek gelir")
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    2611         value = self._sanitize_column(column, value, broadcast=False)
#    2612         self._data.insert(loc, column, value,
# -> 2613                           allow_duplicates=allow_duplicates)
#    2614
#    2615     def assign(self, **kwargs):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in insert(self, loc, item, value, allow_duplicates)
#    4061         if not allow_duplicates and item in self.items:
#    4062             # Should this be a different kind of error??
# -> 4063             raise ValueError('cannot insert {}, already exists'.format(item))
# ...

# %%
dünya
# Out:
#                Ülke     Gelir  gelir düzeyi     Nüfus  Kişi Başına  \
# 0               ABD  20410000  yüksek gelir   323,766        63039
# 1               Çin  14090000  yüksek gelir  1415,045         9957
# 2           Japonya   5170000  yüksek gelir   127,185        40649
# 3           Almanya   4210000  yüksek gelir    82,293        51158
# 4         İngiltere   2940000  yüksek gelir    66,573        44162
# 5            Fransa   2930000  yüksek gelir    65,233        44915
# 6         Hindistan   2850000  yüksek gelir  1354,051         2104
# 7            İtalya   2180000  yüksek gelir     59,29        36768
# 8          Brezilya   2140000  yüksek gelir   210,867        10148
# 9            Kanada   1800000  yüksek gelir    36,953        48710
# 10            Rusya   1720000  yüksek gelir   143,967        11947
# 11       GÜney Kore   1690000  yüksek gelir    51,164        33031
# 12          İspanya   1510000  yüksek gelir    46,397        32545
# ...

# %%
dünya["Gelir"]=dünya["Gelir"] / 1000000

# %%
dünya
# Out:
#                Ülke   Gelir  gelir düzeyi     Nüfus  Kişi Başına  \
# 0               ABD  20.410  yüksek gelir   323,766        63039
# 1               Çin  14.090  yüksek gelir  1415,045         9957
# 2           Japonya   5.170  yüksek gelir   127,185        40649
# 3           Almanya   4.210  yüksek gelir    82,293        51158
# 4         İngiltere   2.940  yüksek gelir    66,573        44162
# 5            Fransa   2.930  yüksek gelir    65,233        44915
# 6         Hindistan   2.850  yüksek gelir  1354,051         2104
# 7            İtalya   2.180  yüksek gelir     59,29        36768
# 8          Brezilya   2.140  yüksek gelir   210,867        10148
# 9            Kanada   1.800  yüksek gelir    36,953        48710
# 10            Rusya   1.720  yüksek gelir   143,967        11947
# 11       GÜney Kore   1.690  yüksek gelir    51,164        33031
# 12          İspanya   1.510  yüksek gelir    46,397        32545
# ...

# %%
dünya["gelir türk lirası"] = dünya["Gelir"]*4.75

# %%
dünya
# Out:
#                Ülke   Gelir  gelir düzeyi     Nüfus  Kişi Başına  \
# 0               ABD  20.410  yüksek gelir   323,766        63039
# 1               Çin  14.090  yüksek gelir  1415,045         9957
# 2           Japonya   5.170  yüksek gelir   127,185        40649
# 3           Almanya   4.210  yüksek gelir    82,293        51158
# 4         İngiltere   2.940  yüksek gelir    66,573        44162
# 5            Fransa   2.930  yüksek gelir    65,233        44915
# 6         Hindistan   2.850  yüksek gelir  1354,051         2104
# 7            İtalya   2.180  yüksek gelir     59,29        36768
# 8          Brezilya   2.140  yüksek gelir   210,867        10148
# 9            Kanada   1.800  yüksek gelir    36,953        48710
# 10            Rusya   1.720  yüksek gelir   143,967        11947
# 11       GÜney Kore   1.690  yüksek gelir    51,164        33031
# 12          İspanya   1.510  yüksek gelir    46,397        32545
# ...

# %%
dünya["KITA"].value_counts()
# Out:
# Avrupa           8
# Asya             7
# Kuzey Amerika    3
# Okyanusya        1
# Güney Amerika    1
# Name: KITA, dtype: int64
